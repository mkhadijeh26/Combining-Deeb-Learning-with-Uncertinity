# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the figure names
first_row = [
    "Training_Predictions_Target_1P1.png",
    "Training_Predictions_Target_1P2.png",
    "Training_Predictions_Target_1P3.png",
    "Training_Predictions_Target_1P4.png",
    "Training_Predictions_Target_1P5.png"
]

second_row = [
    "Training_Predictions_Target_2P1.png",
    "Training_Predictions_Target_2P2.png",
    "Training_Predictions_Target_2P3.png",
    "Training_Predictions_Target_2P4.png",
    "Training_Predictions_Target_2P5.png"
]

# Load the images
images = [mpimg.imread(img) for img in first_row + second_row]

# Create a figure
fig, axes = plt.subplots(2, 5, figsize=(20, 8))

# Plot images in a grid
for i, ax in enumerate(axes.flat):
    ax.imshow(images[i])
    ax.axis('off')  # Hide the axes

# Adjust layout
plt.subplots_adjust(wspace=0, hspace=0)

# Save or show the combined figure
plt.savefig('combined_figure.png')
# Save as a high-quality PDF
plt.savefig('combined_figure.pdf', format='pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the figure names
first_row = [
    "Testing_Predictions_Target_1P1.png",
    "Testing_Predictions_Target_1P2.png",
    "Testing_Predictions_Target_1P3.png",
    "Testing_Predictions_Target_1P4.png",
    "Testing_Predictions_Target_1P5.png"
]

second_row = [
    "Testing_Predictions_Target_2P1.png",
    "Testing_Predictions_Target_2P2.png",
    "Testing_Predictions_Target_2P3.png",
    "Testing_Predictions_Target_2P4.png",
    "Testing_Predictions_Target_2P5.png"
]

# Load the images
images = [mpimg.imread(img) for img in first_row + second_row]

# Create a figure
fig, axes = plt.subplots(2, 5, figsize=(20, 8))

# Plot images in a grid
for i, ax in enumerate(axes.flat):
    ax.imshow(images[i])
    ax.axis('off')  # Hide the axes

# Adjust layout
plt.subplots_adjust(wspace=0, hspace=0)

# Save or show the combined figure
plt.savefig('combined_figure.png')
# Save as a high-quality PDF
plt.savefig('combined_figure2.pdf', format='pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the figure names
first_row = [
    "high_quality_gp_plotG.png",
    "high_quality_gp_plotD.png",
]



# Load the images
images = [mpimg.imread(img) for img in first_row + second_row]

# Create a figure
fig, axes = plt.subplots(1, 2, figsize=(20, 8))

# Plot images in a grid
for i, ax in enumerate(axes.flat):
    ax.imshow(images[i])
    ax.axis('off')  # Hide the axes

# Adjust layout
plt.subplots_adjust(wspace=0, hspace=0)

# Save or show the combined figure
plt.savefig('combined_figure.png')
# Save as a high-quality PDF
plt.savefig('combined_figure.pdf', format='pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the figure names
first_row = [
    "Figure1a.png",
    "Figure1b.png",
]

# Load the images
images = [mpimg.imread(img) for img in first_row + second_row]

# Create a figure
fig, axes = plt.subplots(1, 2, figsize=(20, 8))

# Plot images in a grid
for i, ax in enumerate(axes.flat):
    ax.imshow(images[i])
    ax.axis('off')  # Hide the axes

# Adjust layout
plt.subplots_adjust(wspace=0, hspace=0)

# Save or show the combined figure
plt.savefig('combined_figure.png')
# Save as a high-quality PDF
plt.savefig('combined_figure.pdf', format='pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the figure names
first_row = [
    "KIF_G.png",
    "KIF_D.png",
]

# Load the images
images = [mpimg.imread(img) for img in first_row]

# Create a figure
fig, axes = plt.subplots(1, 2, figsize=(20, 8))

# Plot images in a grid
for i, ax in enumerate(axes.flat):
    ax.imshow(images[i])
    ax.axis('off')  # Hide the axes

# Adjust layout
plt.subplots_adjust(wspace=0, hspace=0)

# Save or show the combined figure
plt.savefig('combined_figureGandD.png')
# Save as a high-quality PDF
plt.savefig('combined_figureGandD.pdf', format='pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the figure names
first_row = [
    "MSEvsEpochs1.png",
    "MSEvsEpochs2.png",
    "MSEvsEpochs3.png",
    "MSEvsEpochs4.png",
    "MSEvsEpochs5.png"
]



# Load the images
images = [mpimg.imread(img) for img in first_row]

# Create a figure
fig, axes = plt.subplots(1, 5, figsize=(20, 8))

# Plot images in a grid
for i, ax in enumerate(axes.flat):
    ax.imshow(images[i])
    ax.axis('off')  # Hide the axes

# Adjust layout
plt.subplots_adjust(wspace=0, hspace=0)

# Save or show the combined figure
plt.savefig('combined_figureMSE.png')
# Save as a high-quality PDF
plt.savefig('combined_figureMSE.pdf', format='pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Define the figure names
first_row = [
    "prediction_errorsFreshG.png",
    "prediction_errorsLTABG.png",
]

second_row = [
    "prediction_errorsFreshD.png",
    "prediction_errorsLTAD.png",
]

# Load the images
images = [mpimg.imread(img) for img in first_row + second_row]

# Create a figure
fig, axes = plt.subplots(2, 2, figsize=(20, 8))

# Plot images in a grid
for i, ax in enumerate(axes.flat):
    ax.imshow(images[i])
    ax.axis('off')  # Hide the axes

# Adjust layout
plt.subplots_adjust(wspace=0, hspace=0)

# Save or show the combined figure
plt.savefig('combined_figureGandDFreshandLTA.png')
# Save as a high-quality PDF
plt.savefig('combined_figure2.pdf', format='pdf', dpi=300)
plt.show()
