# %% [markdown]
# **Fresh Bitumen (Sample 92)**
# ---

# %%
import matplotlib.pyplot as plt

# Data
dnn_predictions = [367228448, 279717632, 316385984, 331990528, 304976032, 299165070]
true_value = 299000000
dnn_labels = ['DNN1', 'DNN2', 'DNN3', 'DNN4', 'DNN5', 'DNN+GP']
colors = ['blue', 'green', 'red', 'purple', 'orange', 'cyan']
true_color = 'gold'

# Calculate errors
errors = [abs(pred - true_value) for pred in dnn_predictions]

# Setting up the figure for error bars
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting Error Bars
ax.errorbar(dnn_labels, dnn_predictions, yerr=errors, fmt='o', color='black', label='Prediction Errors')
ax.scatter(dnn_labels, [true_value]*len(dnn_labels), color=true_color, marker='x', s=100, label='True Value', zorder=5)

# Bolding the title and axes labels
ax.set_title(r'Error Bars Showing Prediction Deviations of G$^*$ (Fresh Bitumen)', fontweight='bold', fontsize=16)
ax.set_xlabel('Models', fontweight='bold', fontsize=14)
ax.set_ylabel('Predictions', fontweight='bold', fontsize=14)

# Bolding tick labels
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
    label.set_fontsize(14)
ax.legend()

# Adjust layout to prevent cutting off labels
plt.tight_layout()

# Save the plot as a high-quality PDF
plt.savefig('prediction_errorsFreshG.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.savefig('prediction_errorsFreshG.png', dpi=300, bbox_inches='tight')
# Display the plot
plt.show()

# %% [markdown]
# **LTA Bitumen (Sample 319)**
# ---

# %%
import matplotlib.pyplot as plt

# Data
dnn_predictions = [4.20E+07,	4.32E+07,	4.42E+07,	4.29E+07,	3.92E+07,  2.59E+07]
true_value = 2.30E+07
dnn_labels = ['DNN1', 'DNN2', 'DNN3', 'DNN4', 'DNN5', 'DNN+GP']
colors = ['blue', 'green', 'red', 'purple', 'orange', 'cyan']
true_color = 'gold'

# Calculate errors
errors = [abs(pred - true_value) for pred in dnn_predictions]

# Setting up the figure for error bars
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting Error Bars
ax.errorbar(dnn_labels, dnn_predictions, yerr=errors, fmt='o', color='black', label='Prediction Errors')
ax.scatter(dnn_labels, [true_value]*len(dnn_labels), color=true_color, marker='x', s=100, label='True Value', zorder=5)

# Bolding the title and axes labels
ax.set_title(r'Error Bars Showing Prediction Deviations of G$^*$ (LTA Bitumen)', fontweight='bold', fontsize=16)
ax.set_xlabel('Models', fontweight='bold', fontsize=14)
ax.set_ylabel('Predictions', fontweight='bold', fontsize=14)

# Bolding tick labels
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
    label.set_fontsize(14)
ax.legend()

# Adjust layout to prevent cutting off labels
plt.tight_layout()

# Save the plot as a high-quality PDF
plt.savefig('prediction_errorsLTABD.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.savefig('prediction_errorsLTABD.png', dpi=300, bbox_inches='tight')
# Display the plot
plt.show()

# %% [markdown]
# **LTA Bitumen (Sample 319)**
# ---

# %%
import matplotlib.pyplot as plt

# Data
dnn_predictions = [30.72919846, 31.18275642 , 31.3528614, 30.20849419 , 30.71707344, 31.37591039]
true_value = 35.02
dnn_labels = ['DNN1', 'DNN2', 'DNN3', 'DNN4', 'DNN5', 'DNN+GP']
colors = ['blue', 'green', 'red', 'purple', 'orange', 'cyan']
true_color = 'gold'

# Calculate errors
errors = [abs(pred - true_value) for pred in dnn_predictions]

# Setting up the figure for error bars
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting Error Bars
ax.errorbar(dnn_labels, dnn_predictions, yerr=errors, fmt='o', color='black', label='Prediction Errors')
ax.scatter(dnn_labels, [true_value]*len(dnn_labels), color=true_color, marker='x', s=100, label='True Value', zorder=5)

# Bolding the title and axes labels
ax.set_title(r'Error Bars Showing Prediction Deviations of δ (LTA Bitumen)', fontweight='bold', fontsize=16)
ax.set_xlabel('Models', fontweight='bold', fontsize=14)
ax.set_ylabel('Predictions', fontweight='bold', fontsize=14)

# Bolding tick labels
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
    label.set_fontsize(14)
ax.legend()

# Adjust layout to prevent cutting off labels
plt.tight_layout()

# Save the plot as a high-quality PDF
plt.savefig('prediction_errorsLTAD.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.savefig('prediction_errorsLTAD.png', dpi=300, bbox_inches='tight')
# Display the plot
plt.show()

# %% [markdown]
# **Fresh Bitumen (Sample 92)**
# ---

# %%
import matplotlib.pyplot as plt
# Data
dnn_predictions = [19.35820389,	20.57032776,	19.43695259,	20.86990166,	20.04834747, 17.96380571]
true_value = 17
dnn_labels = ['DNN1', 'DNN2', 'DNN3', 'DNN4', 'DNN5', 'DNN+GP']
colors = ['blue', 'green', 'red', 'purple', 'orange', 'cyan']
true_color = 'gold'

# Calculate errors
errors = [abs(pred - true_value) for pred in dnn_predictions]

# Setting up the figure for error bars
fig, ax = plt.subplots(figsize=(10, 6))

# Plotting Error Bars
ax.errorbar(dnn_labels, dnn_predictions, yerr=errors, fmt='o', color='black', label='Prediction Errors')
ax.scatter(dnn_labels, [true_value]*len(dnn_labels), color=true_color, marker='x', s=100, label='True Value', zorder=5)

# Bolding the title and axes labels
ax.set_title(r'Error Bars Showing Prediction Deviations of δ (Fresh Bitumen)', fontweight='bold', fontsize=16)
ax.set_xlabel('Models', fontweight='bold', fontsize=14)
ax.set_ylabel('Predictions', fontweight='bold', fontsize=14)

# Bolding tick labels
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
    label.set_fontsize(14)
ax.legend()

# Adjust layout to prevent cutting off labels
plt.tight_layout()

# Save the plot as a high-quality PDF
plt.savefig('prediction_errorsFreshD.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.savefig('prediction_errorsFreshD.png', dpi=300, bbox_inches='tight')
# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the plots
data = [
    {
        'dnn_predictions': [367228448, 279717632, 316385984, 331990528, 304976032, 299165070],
        'true_value': 299000000,
        'title': r'Error Bars Showing Prediction Deviations of G$^*$ (Fresh Bitumen)',
        'file_name': 'prediction_errorsFreshG'
    },
    {
        'dnn_predictions': [4.20E+07, 4.32E+07, 4.42E+07, 4.29E+07, 3.92E+07, 2.59E+07],
        'true_value': 2.30E+07,
        'title': r'Error Bars Showing Prediction Deviations of G$^*$ (LTA Bitumen)',
        'file_name': 'prediction_errorsLTABD'
    },

    {
        'dnn_predictions': [19.35820389, 20.57032776, 19.43695259, 20.86990166, 20.04834747, 17.96380571],
        'true_value': 17,
        'title': r'Error Bars Showing Prediction Deviations of δ (Fresh Bitumen)',
        'file_name': 'prediction_errorsFreshD'
    },

    
    {
        'dnn_predictions': [30.72919846, 31.18275642 , 31.3528614, 30.20849419 , 30.71707344, 31.37591039],
        'true_value': 35.02,
        'title': r'Error Bars Showing Prediction Deviations of δ (LTA Bitumen)',
        'file_name': 'prediction_errorsLTAD'
    }
]

dnn_labels = ['DNN1', 'DNN2', 'DNN3', 'DNN4', 'DNN5', 'DNN+GP']
colors = ['blue', 'green', 'red', 'purple', 'orange', 'cyan']
true_color = 'gold'

# Setting up the figure for subplots
fig, axes = plt.subplots(2, 2, figsize=(20, 12))
axes = axes.flatten()

# Generating each subplot
for i, ax in enumerate(axes):
    dnn_predictions = data[i]['dnn_predictions']
    true_value = data[i]['true_value']
    title = data[i]['title']
    
    # Calculate errors
    errors = [abs(pred - true_value) for pred in dnn_predictions]
    
    # Plotting Error Bars
    ax.errorbar(dnn_labels, dnn_predictions, yerr=errors, fmt='o', color='black', label='Prediction Errors')
    ax.scatter(dnn_labels, [true_value]*len(dnn_labels), color=true_color, marker='x', s=100, label='True Value', zorder=5)
    
    # Bolding the title and axes labels
    ax.set_title(title, fontweight='bold', fontsize=16)
    ax.set_xlabel('Models', fontweight='bold', fontsize=14)
    ax.set_ylabel('Predictions', fontweight='bold', fontsize=14)
    
    # Bolding tick labels
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_fontweight('bold')
        label.set_fontsize(14)
    ax.legend(prop={'weight': 'bold', 'size': 10})

# Adjust layout to prevent cutting off labels
plt.tight_layout()

# Save the plot as a high-quality PDF
plt.savefig('prediction_errors_combined.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.savefig('prediction_errors_combined.png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter, FuncFormatter

# Data for the plots
data = [
    {
        'dnn_predictions': [1.52E+05, 8.54E+04, 1.59E+05, 1.18E+05, 1.65E+05, 3.16E+05],
        'true_value': 4.81E+05,
        'title': r'Error Bars Showing Prediction Deviations of G$^*$ (STA Bitumen + Fillers)',
        'file_name': 'prediction_errorsFreshG'
    },
    {
        'dnn_predictions': [7.33E+01, 7.23E+01, 73.3527832, 74.01119995, 72.86924744, 71.57555583],
        'true_value': 70.02774915,
        'title': r'Error Bars Showing Prediction Deviations of δ (STA Bitumen + Fillers)',
        'file_name': 'prediction_errorsLTABD'
    },
]

dnn_labels = ['DNN1', 'DNN2', 'DNN3', 'DNN4', 'DNN5', 'DNN+GP']
colors = ['blue', 'green', 'red', 'purple', 'orange', 'cyan']
true_color = 'gold'

# Setting up the figure for subplots
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes = axes.flatten()

# Generating each subplot
for i, ax in enumerate(axes):
    dnn_predictions = data[i]['dnn_predictions']
    true_value = data[i]['true_value']
    title = data[i]['title']
    
    # Calculate errors
    errors = [abs(pred - true_value) for pred in dnn_predictions]
    
    # Plotting Error Bars
    ax.errorbar(dnn_labels, dnn_predictions, yerr=errors, fmt='o', color='black', label='Prediction Errors')
    ax.scatter(dnn_labels, [true_value]*len(dnn_labels), color=true_color, marker='x', s=100, label='True Value', zorder=5)
    
    # Bolding the title and axes labels
    ax.set_title(title, fontweight='bold', fontsize=14)
    ax.set_xlabel('Models', fontweight='bold', fontsize=14)
    ax.set_ylabel('Predictions', fontweight='bold', fontsize=14)
    
    # Bolding tick labels
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_fontweight('bold')
        label.set_fontsize(14)

    # Apply scientific notation to the y-axis of the left plot
    if i == 0:
        ax.yaxis.set_major_formatter(ScalarFormatter())
        ax.yaxis.get_major_formatter().set_powerlimits((0, 1))
    else:  # Apply regular numbers to the y-axis of the right plot
        ax.yaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{int(x)}'))
    
    ax.legend(prop={'weight': 'bold', 'size': 10})

# Adjust layout to prevent cutting off labels
plt.tight_layout()

# Save the plot as a high-quality PDF
plt.savefig('prediction_errors_combinedMastic.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.savefig('prediction_errors_combinedMastic.png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()

# %% [markdown]
# **Mastic Errors
# --**

# %%
import matplotlib.pyplot as plt

# Data for the plots
data = [
    {
        'dnn_predictions': [1.52E+05, 8.54E+04, 1.59E+05, 1.18E+05, 1.65E+05, 3.16E+05],
        'true_value': 4.81E+05,
        'title': r'Error Bars Showing Prediction Deviations of G$^*$ (STA Bitumen + Fillers)',
        'file_name': 'prediction_errorsFreshG'
    },
    {
        'dnn_predictions': [7.33E+01, 7.23E+01, 73.3527832, 74.01119995, 72.86924744, 71.57555583],
        'true_value': 70.02774915,
        'title': r'Error Bars Showing Prediction Deviations of δ (STA Bitumen + Fillers)',
        'file_name': 'prediction_errorsLTABD'
    },
]

dnn_labels = ['DNN1', 'DNN2', 'DNN3', 'DNN4', 'DNN5', 'DNN+GP']
true_color = 'gold'

# First Figure (e) - G* (STA Bitumen + Fillers)
# Scale the data for the first plot
scale_factor = 1e5
dnn_predictions_scaled = [pred / scale_factor for pred in data[0]['dnn_predictions']]
true_value_scaled = data[0]['true_value'] / scale_factor
errors = [abs(pred - data[0]['true_value']) for pred in data[0]['dnn_predictions']]
errors_scaled = [err / scale_factor for err in errors]

fig1, ax1 = plt.subplots(figsize=(7, 5))
ax1.errorbar(dnn_labels, dnn_predictions_scaled, yerr=errors_scaled, fmt='o', color='black', 
             markersize=5, capsize=3, label='Prediction Errors')
ax1.scatter(dnn_labels, [true_value_scaled]*len(dnn_labels), color=true_color, marker='x', 
            s=50, label='True Value', zorder=5)

ax1.set_title('', fontweight='bold', fontsize=14)
ax1.set_xlabel('Models', fontweight='bold', fontsize=18)
ax1.set_ylabel('Predictions (×10⁵)', fontweight='bold', fontsize=18)

for label in ax1.get_xticklabels() + ax1.get_yticklabels():
    label.set_fontweight('bold')
    label.set_fontsize(14)

ax1.legend(fontsize=10)
plt.tight_layout(pad=0.5)
plt.savefig(f"{data[0]['file_name']}_e.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.savefig(f"{data[0]['file_name']}_e.png", dpi=300, bbox_inches='tight')
plt.show()

# Second Figure (f) - δ (STA Bitumen + Fillers)
# No scaling needed for the second plot
dnn_predictions = data[1]['dnn_predictions']
true_value = data[1]['true_value']
errors = [abs(pred - true_value) for pred in dnn_predictions]

fig2, ax2 = plt.subplots(figsize=(7, 5))
ax2.errorbar(dnn_labels, dnn_predictions, yerr=errors, fmt='o', color='black', 
             markersize=5, capsize=3, label='Prediction Errors')
ax2.scatter(dnn_labels, [true_value]*len(dnn_labels), color=true_color, marker='x', 
            s=50, label='True Value', zorder=5)

ax2.set_title(' ', fontweight='bold', fontsize=14)
ax2.set_xlabel('Models', fontweight='bold', fontsize=18)
ax2.set_ylabel('Predictions', fontweight='bold', fontsize=18)

for label in ax2.get_xticklabels() + ax2.get_yticklabels():
    label.set_fontweight('bold')
    label.set_fontsize(14)

ax2.legend(fontsize=10)
plt.tight_layout(pad=0.5)
plt.savefig(f"{data[1]['file_name']}_f.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.savefig(f"{data[1]['file_name']}_f.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# **Mastivc Error - Low Stiffness 30 (GPa)**

# %%
import matplotlib.pyplot as plt

# Data for the plots
data = [
    {
        'dnn_predictions': [7.54E+04, 6.32E+04, 7.14E+04, 1.44E+05, 7.431E+04, 9.8123E+04],
        'true_value': 9.85E+04,
        'title': r'Error Bars Showing Prediction Deviations of G$^*$ (STA Bitumen + Fillers)',
        'file_name': 'prediction_errorsFreshG'
    },
    {
        'dnn_predictions': [7.43E+01, 7.23E+01, 71.3527832, 74.1, 74.224, 73.564],
        'true_value': 73.02774915,
        'title': r'Error Bars Showing Prediction Deviations of δ (STA Bitumen + Fillers)',
        'file_name': 'prediction_errorsLTABD'
    },
]

dnn_labels = ['DNN1', 'DNN2', 'DNN3', 'DNN4', 'DNN5', 'DNN+GP']
true_color = 'gold'

# First Figure (e) - G* (STA Bitumen + Fillers)
# Scale the data for the first plot
scale_factor = 1e5
dnn_predictions_scaled = [pred / scale_factor for pred in data[0]['dnn_predictions']]
true_value_scaled = data[0]['true_value'] / scale_factor
errors = [abs(pred - data[0]['true_value']) for pred in data[0]['dnn_predictions']]
errors_scaled = [err / scale_factor for err in errors]

fig1, ax1 = plt.subplots(figsize=(7, 5))
ax1.errorbar(dnn_labels, dnn_predictions_scaled, yerr=errors_scaled, fmt='o', color='black', 
             markersize=5, capsize=3, label='Prediction Errors')
ax1.scatter(dnn_labels, [true_value_scaled]*len(dnn_labels), color=true_color, marker='x', 
            s=50, label='True Value', zorder=5)

ax1.set_title('', fontweight='bold', fontsize=14)
ax1.set_xlabel('Models', fontweight='bold', fontsize=18)
ax1.set_ylabel('Predictions (×10⁵)', fontweight='bold', fontsize=18)

for label in ax1.get_xticklabels() + ax1.get_yticklabels():
    label.set_fontweight('bold')
    label.set_fontsize(14)

ax1.legend(fontsize=10)
plt.tight_layout(pad=0.5)
plt.savefig(f"{data[0]['file_name']}_e.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.savefig(f"{data[0]['file_name']}_e.png", dpi=300, bbox_inches='tight')
plt.show()

# Second Figure (f) - δ (STA Bitumen + Fillers)
# No scaling needed for the second plot
dnn_predictions = data[1]['dnn_predictions']
true_value = data[1]['true_value']
errors = [abs(pred - true_value) for pred in dnn_predictions]

fig2, ax2 = plt.subplots(figsize=(7, 5))
ax2.errorbar(dnn_labels, dnn_predictions, yerr=errors, fmt='o', color='black', 
             markersize=5, capsize=3, label='Prediction Errors')
ax2.scatter(dnn_labels, [true_value]*len(dnn_labels), color=true_color, marker='x', 
            s=50, label='True Value', zorder=5)

ax2.set_title(' ', fontweight='bold', fontsize=14)
ax2.set_xlabel('Models', fontweight='bold', fontsize=18)
ax2.set_ylabel('Predictions', fontweight='bold', fontsize=18)

for label in ax2.get_xticklabels() + ax2.get_yticklabels():
    label.set_fontweight('bold')
    label.set_fontsize(14)

ax2.legend(fontsize=10)
plt.tight_layout(pad=0.5)
plt.savefig(f"{data[1]['file_name']}_f.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.savefig(f"{data[1]['file_name']}_f.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
**Mastivc Error - Low Stiffness 100 (GPa)**

# %%
import matplotlib.pyplot as plt

# Data for the plots
data = [
    {
        'dnn_predictions': [4.32E+06, 4.512E+06, 5.59E+06, 8.18E+06, 8.125E+06, 6.042E+06],
        'true_value': 6.234E+06,
        'title': r'Error Bars Showing Prediction Deviations of G$^*$ (STA Bitumen + Fillers)',
        'file_name': 'prediction_errorsFreshG'
    },
    {
        'dnn_predictions': [6.63E+01, 6.23E+01, 65.3527832, 68.01119995, 62.86924744, 64.57555583],
        'true_value': 64.02774915,
        'title': r'Error Bars Showing Prediction Deviations of δ (STA Bitumen + Fillers)',
        'file_name': 'prediction_errorsLTABD'
    },
]

dnn_labels = ['DNN1', 'DNN2', 'DNN3', 'DNN4', 'DNN5', 'DNN+GP']
true_color = 'gold'

# First Figure (e) - G* (STA Bitumen + Fillers)
# Scale the data for the first plot
scale_factor = 1e5
dnn_predictions_scaled = [pred / scale_factor for pred in data[0]['dnn_predictions']]
true_value_scaled = data[0]['true_value'] / scale_factor
errors = [abs(pred - data[0]['true_value']) for pred in data[0]['dnn_predictions']]
errors_scaled = [err / scale_factor for err in errors]

fig1, ax1 = plt.subplots(figsize=(7, 5))
ax1.errorbar(dnn_labels, dnn_predictions_scaled, yerr=errors_scaled, fmt='o', color='black', 
             markersize=5, capsize=3, label='Prediction Errors')
ax1.scatter(dnn_labels, [true_value_scaled]*len(dnn_labels), color=true_color, marker='x', 
            s=50, label='True Value', zorder=5)

ax1.set_title('', fontweight='bold', fontsize=14)
ax1.set_xlabel('Models', fontweight='bold', fontsize=18)
ax1.set_ylabel('Predictions (×10⁵)', fontweight='bold', fontsize=18)

for label in ax1.get_xticklabels() + ax1.get_yticklabels():
    label.set_fontweight('bold')
    label.set_fontsize(14)

ax1.legend(fontsize=10)
plt.tight_layout(pad=0.5)
plt.savefig(f"{data[0]['file_name']}_e.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.savefig(f"{data[0]['file_name']}_e.png", dpi=300, bbox_inches='tight')
plt.show()

# Second Figure (f) - δ (STA Bitumen + Fillers)
# No scaling needed for the second plot
dnn_predictions = data[1]['dnn_predictions']
true_value = data[1]['true_value']
errors = [abs(pred - true_value) for pred in dnn_predictions]

fig2, ax2 = plt.subplots(figsize=(7, 5))
ax2.errorbar(dnn_labels, dnn_predictions, yerr=errors, fmt='o', color='black', 
             markersize=5, capsize=3, label='Prediction Errors')
ax2.scatter(dnn_labels, [true_value]*len(dnn_labels), color=true_color, marker='x', 
            s=50, label='True Value', zorder=5)

ax2.set_title(' ', fontweight='bold', fontsize=14)
ax2.set_xlabel('Models', fontweight='bold', fontsize=18)
ax2.set_ylabel('Predictions', fontweight='bold', fontsize=18)

for label in ax2.get_xticklabels() + ax2.get_yticklabels():
    label.set_fontweight('bold')
    label.set_fontsize(14)

ax2.legend(fontsize=10)
plt.tight_layout(pad=0.5)
plt.savefig(f"{data[1]['file_name']}_f.pdf", format='pdf', dpi=300, bbox_inches='tight')
plt.savefig(f"{data[1]['file_name']}_f.png", dpi=300, bbox_inches='tight')
plt.show()
